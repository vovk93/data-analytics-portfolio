# %% [markdown]
# # Data Analyst Professional Practical Exam Submission

# %% [markdown]
# ## 📝 Task List
#
# Your written report should include written text summaries and graphics of the following:
# - Data validation:
#   - Describe validation and cleaning steps for every column in the data
# - Exploratory Analysis:
#   - Include two different graphics showing single variables only to demonstrate the characteristics of data
#   - Include at least one graphic showing two or more variables to represent the relationship between features
#   - Describe your findings
# - Definition of a metric for the business to monitor
#   - How should the business use the metric to monitor the business problem
#   - Can you estimate initial value(s) for the metric based on the current data
# - Final summary including recommendations that the business should undertake
#
# *Start writing report here..*

# %% [markdown]
# # Data validation and cleaning
#
# - Dataset columns: `week`, `sales_method`, `customer_id`, `nb_sold`, `revenue`, `years_as_customer`, `nb_site_visits`, `state`
# - Missing values found only in `revenue`.
# - `sales_method` has 5 values; reduced to 3 main types (`Email`, `Call`, `Email + Call`) by correcting mistyped entries.
# - No duplicates in `customer_id`. Outliers in `years_as_customer` > 40 removed.
# - Revenue missing values imputed using average price per product by sales method.

# %% [markdown]
# # Exploratory Analysis
#
# ## Customer Count by Sales Method
#
# ![Breakdown by approach](figures/customer_count_by_sales_method.png)
#
# - **Email**: most frequent, easiest method.
# - **Call**: second most frequent, more time-consuming.
# - **Email + Call**: least frequent.

# %% [markdown]
# ## Overall Revenue
#
# | Summary Statistic   | Value |
# | :----------------- | :---- |
# | Number of entries  | 14998 |
# | Average            | 94.84 |
# | Standard deviation | 47.35 |
# | Minimum            | 32.54 |
# | 25th percentile    | 52.76 |
# | 50th percentile    | 90.00 |
# | 75th percentile    | 107.86 |
# | Maximum            | 238.32 |

# %% [markdown]
# ## Call Approach
#
# | Summary Statistic   | Value |
# | :----------------- | :---- |
# | Number of entries  | 4961  |
# | Average            | 47.57 |
# | Standard deviation | 8.60  |
# | Minimum            | 32.54 |
# | 25th percentile    | 41.46 |
# | 50th percentile    | 48.23 |
# | 75th percentile    | 52.70 |
# | Maximum            | 71.36 |

# %% [markdown]
# ## Email Approach
#
# | Summary Statistic   | Value |
# | :----------------- | :---- |
# | Number of entries  | 7465  |
# | Average            | 96.67 |
# | Standard deviation | 11.30 |
# | Minimum            | 74.04 |
# | 25th percentile    | 87.52 |
# | 50th percentile    | 95.04 |
# | 75th percentile    | 104.60 |
# | Maximum            | 148.97 |

# %% [markdown]
# ## Email + Call Approach
#
# | Summary Statistic   | Value |
# | :----------------- | :---- |
# | Number of entries  | 2572  |
# | Average            | 180.70|
# | Standard deviation | 29.49 |
# | Minimum            | 103.87|
# | 25th percentile    | 155.80|
# | 50th percentile    | 183.70|
# | 75th percentile    | 191.28|
# | Maximum            | 238.32 |

# %% [markdown]
# ## Revenue Efficiency Table
#
# | Sales method   | Revenue    | Number of customers | Hours spent | Revenue per hour |
# | :------------ | :-------- | :---------------- | :---------- | :--------------- |
# | Call          | 236065.80 | 4961               | 2481        | 95               |
# | Email         | 721705.72 | 7465               | 19          | 37984            |
# | Email + Call  | 464773.97 | 2572               | 428         | 1085             |
